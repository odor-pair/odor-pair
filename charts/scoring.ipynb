# Display the common keys
print(common_keys)
# Out:
# {'mentholic', 'fruity', 'minty', 'nutty', 'jammy', 'berry', 'clean', 'licorice', 'acidic', 'dairy', 'herbal', 'winey', 'alliaceous', 'green', 'chemical', 'spicy', 'waxy', 'solvent', 'balsamic', 'brown', 'coffee', 'soapy', 'camphoreous', 'aromatic', 'musk', 'sulfurous', 'vegetable', 'burnt', 'animal', 'fusel', 'medicinal', 'bready', 'melon', 'cooling', 'woody', 'sour', 'onion', 'tropical', 'anise', 'fungal', 'ethereal', 'rummy', 'coconut', 'tonka', 'aldehydic', 'coumarinic', 'citrus', 'earthy', 'phenolic', 'cocoa', 'fresh', 'amber', 'fermented', 'musty', 'powdery', 'marine', 'sweet', 'creamy', 'orris', 'chocolate', 'cheesy', 'floral', 'roasted', 'honey', 'bitter', 'fatty', 'oily', 'caramellic', 'vanilla', 'buttery', 'meaty', 'mossy', 'estery', 'thujonic'}

# %%
# Convert the list of dictionaries to a DataFrame using only the common keys
df = pd.DataFrame([{k: d[k] for k in common_keys} for d in scores], index=["MPNN-GNN", "GIN-GNN","Morgan Fingerprint"])
sorted_df = df[sorted(df.columns)]
sorted_df
# Out:
#                       acidic  aldehydic  alliaceous     amber    animal  \
# MPNN-GNN            0.982218   0.906099    0.893936  0.945604  0.592632
# GIN-GNN             0.994070   0.865554    0.974623  0.957384  0.641791
# Morgan Fingerprint  0.944046   0.811846    0.703524  0.864588  0.850705
#
#                        anise  aromatic  balsamic     berry    bitter  ...  \
# MPNN-GNN            0.850770  0.781771  0.891297  0.909165  0.451608  ...
# GIN-GNN             0.920212  0.648730  0.708070  0.767772  0.170719  ...
# Morgan Fingerprint  0.859071  0.391180  0.782616  0.807117  0.577802  ...
#
#                     sulfurous     sweet  thujonic     tonka  tropical  \
# MPNN-GNN             0.819767  0.576858  0.534290  0.823265  0.521778
# GIN-GNN              0.940721  0.167163  0.760540  0.887292  0.548200
# Morgan Fingerprint   0.820101  0.652695  0.975902  0.386376  0.451487
#
#                      vanilla  vegetable      waxy     winey     woody
# ...

# %%
len(df.columns)
# Out:
# 74

# %%
import json
with open("../dataset/single_fold.json") as f:
    full_data = json.load(f)
print(full_data.keys())
print(len(full_data["train"]),len(full_data["test"]),len(common_keys))
# Out:
# dict_keys(['train', 'test', 'covered_notes'])
# 43992 39554 74

# %%
with open("../dataset/full.json") as f:
    all_data = json.load(f)
len(all_data),len(all_data) - (len(full_data["train"]) + len(full_data["test"]))
# Out:
# (166814, 83268)

# %%
import collections
notes = collections.Counter()
for d in full_data["test"]:
    notes.update(d["blend_notes"])
notes_frac = {n:(c/sum(notes.values())) for (n,c) in notes.most_common() if n in common_keys}
next(iter(notes_frac.items()))
# Out:
# ('fruity', 0.23331322327647672)

# %%
def calc_micro_average(row):
     return sum(sorted_df.loc[row][col] * weight for col, weight in notes_frac.items())
calc_micro_average("Morgan Fingerprint")
# Out:
# 0.6744997877392639

# %%
import matplotlib.pyplot as plt
import numpy as np


def make_multi_row_performance(fname,aurocs,df,rows,hspace=.5):
    counter_per_row = int(np.ceil(len(df.columns)/rows))
    fig, axs = utils.standard_fig_ax(x=rows)
    fig.subplots_adjust(hspace=hspace)  # Increase vertical spacing
    w = (1 / len(df.index)) - .08


    column_chunks = [df.columns[i:i + counter_per_row] for i in range(0, len(df.columns), counter_per_row)]
    for i, columns in enumerate(column_chunks):
        for j,m in enumerate(df.index):
            x_offsets = np.arange(len(columns)) + w * j  # Offsetting each bar by 0.1 per row
            axs[i].bar(x_offsets, df.loc[m, columns], width=w, align="edge",label=m)

        axs[i].axhline(y=0.5,color='grey',linestyle='dashed')
        axs[i].tick_params(axis='x', rotation=35)
        axs[i].set_ylim(0,1)
        axs[i].set_xticks(ticks=np.arange(len(columns))+w*len(df.index)/2,labels=columns)
        for label in axs[i].get_xticklabels():
            label.set_ha('right')  # 'ha' is shorthand for 'horizontalalignment'

        
    # Get the handles from any axis
    handles, _ = axs[-1].get_legend_handles_labels()
    labels = [f"{m} (AUROC={aurocs[m]:.2f})" for m in df.index]
    legend = plt.figlegend(handles, labels, bbox_to_anchor=(.72,.83,.2,.1))

    plt.suptitle("AUROC Comparison on Blended Pair Task\nby Model and Odor Label",y=.93)
    fig.set_size_inches(15,10)
    utils.save_figures(fname,fig)
    plt.show()
    
aurocs = {m:calc_micro_average(m) for m in sorted_df.index}
make_multi_row_performance("pairall_3rows",aurocs, sorted_df,3)

# %%
make_multi_row_performance("pairall_4rows",aurocs,sorted_df,4,hspace=.6)

# %%
import os
import json

# Define the path to the results folder
results_folder = 'results'

# Initialize variables to keep track of the file with the highest TOTAL
max_total = None
max_total_file = None

# Iterate over all files in the results folder
for file_name in os.listdir(results_folder):
    # Check if the file is a JSON file
    if file_name.endswith('.json'):
        # Construct the full file path
        file_path = os.path.join(results_folder, file_name)
        if not "single" in file_path:
            continue
        # Open and read the JSON file
        with open(file_path, 'r') as json_file:
            data = json.load(json_file)
            # Print the file name and the TOTAL value
            print(f"File: {file_name}, TOTAL: {data.get('TOTAL')}")
           # Get the TOTAL value
            total = data.get('TOTAL')
            # Check if this is the highest TOTAL we've seen so far
            if max_total is None or (total is not None and total > max_total):
                max_total = total
                max_total_file = file_name
print(f"File with the highest TOTAL: {max_total_file}, TOTAL: {max_total}")
# Out:
# File: odor_single_single_valid_trial_2_scores.json, TOTAL: 0.8860209140960945
# File: odor_single_single_valid_trial_1_scores.json, TOTAL: 0.8883760621060871
# File: odor_single_mix_test_trial_3_scores.json, TOTAL: 0.8158377356237959
# File: odor_single_single_valid_trial_3_scores.json, TOTAL: 0.8881854032410932
# File: odor_single_mix_test_trial_1_scores.json, TOTAL: 0.8146943846281854
# File: odor_single_mix_test_trial_2_scores.json, TOTAL: 0.8141080431403808
# File with the highest TOTAL: odor_single_single_valid_trial_1_scores.json, TOTAL: 0.8883760621060871

# %%
016501288306562, "musk": 0.9238443164254602, "musty": 0.7360505529225908, "nutty": 0.8732616199189034, "oily": 0.8680708854549913, "onion": 0.979758149316509, "orris": 0.8959842001316656, "phenolic": 0.9518927444794953, "powdery": 0.8574252532740301, "roasted": 0.9464672232529374, "rummy": 0.8500772797527049, "soapy": 0.9056748466257669, "solvent": 0.8211538461538461, "sour": 0.8668209876543211, "spicy": 0.8700390189520625, "sulfurous": 0.9827064546748931, "sweet": 0.815999531835206, "tropical": 0.9034210526315789, "vanilla": 0.973617601246106, "vegetable": 0.8979133226324238, "waxy": 0.9276510604241697, "winey": 0.9219341044898854, "woody": 0.8784298780487805}
gin = {"TOTAL": 0.8860209140960945, "aldehydic": 0.8628309968847352, "alliaceous": 0.9737847222222222, "amber": 0.9188271604938272, "animal": 0.9065420560747663, "anise": 0.8816917240410285, "aromatic": 0.8349023464943095, "balsamic": 0.9286502546689304, "berry": 0.8589409722222222, "bitter": 0.7885636021229241, "burnt": 0.8458495618305745, "buttery": 0.8779513888888889, "camphoreous": 0.9543911168211434, "caramellic": 0.9670027955271565, "cheesy": 0.9148612463485881, "chocolate": 0.7733595616130392, "citrus": 0.8690322805306961, "clean": 0.924125333708023, "cocoa": 0.789024502156557, "coconut": 0.8246913580246914, "coffee": 0.9499222395023328, "cooling": 0.9359615384615385, "coumarinic": 0.9710335747202106, "creamy": 0.8109408933497682, "dairy": 0.8492990654205608, "earthy": 0.7629449838187702, "ethereal": 0.9533749290981282, "fatty": 0.9019800942902043, "fermented": 0.934663975480302, "floral": 0.8947100063734863, "fresh": 0.8165142653156493, "fruity": 0.923095458400802, "green": 0.8904183535762482, "herbal": 0.8120594559222212, "honey": 0.7896701388888889, "meaty": 0.964189827944791, "medicinal": 0.8902585173771614, "melon": 0.8653504880212954, "minty": 0.9016501288306562, "musk": 0.9238443164254602, "musty": 0.7360505529225908, "nutty": 0.8732616199189034, "oily": 0.8680708854549913, "onion": 0.979758149316509, "orris": 0.8959842001316656, "phenolic": 0.9518927444794953, "powdery": 0.8574252532740301, "roasted": 0.9464672232529374, "rummy": 0.8500772797527049, "soapy": 0.9056748466257669, "solvent": 0.8211538461538461, "sour": 0.8668209876543211, "spicy": 0.8700390189520625, "sulfurous": 0.9827064546748931, "sweet": 0.815999531835206, "tropical": 0.9034210526315789, "vanilla": 0.973617601246106, "vegetable": 0.8979133226324238, "waxy": 0.9276510604241697, "winey": 0.9219341044898854, "woody": 0.8784298780487805}

scores = [openpom,gin,fingerprint]
common_keys = set(scores[0].keys()).intersection(*[d.keys() for d in scores])

df = pd.DataFrame([{k: d[k] for k in common_keys} for d in scores], index=["MPNN-GNN", "GIN-GNN","Morgan Fingerprint"])
sorted_df = df[sorted(df.columns)]
aurocs = {m:sorted_df.loc[m]["TOTAL"] for m in sorted_df.index}
make_multi_row_performance("singleall_3rows",aurocs, sorted_df,3)

# %%
make_multi_row_performance("singleall_4rows",aurocs, sorted_df,4)
